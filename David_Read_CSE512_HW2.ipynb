# %% [markdown]
# ![](./Endoth_only__UMAP_partitionLabelcolored.png)

# %%
# ![image](./Endoth_only__UMAP_partitionLabelcolored.png)

# %% [markdown]
# <img src=Endoth_only__UMAP_partitionLabelcolored.png>

# %%
library(png)
# img <- readPNG(system.file("img", "Rlogo.png", package="png"))
img <- readPNG("Endoth_only__UMAP_partitionLabelcolored.png")
grid::grid.raster(img)
# Out:
# plot without title

# %%
img <- readPNG("HM10_UMAP_cluster_cell_typecolored.png")
grid::grid.raster(img)
# Out:
# plot without title
