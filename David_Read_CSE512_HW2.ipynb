# %% [markdown]
# CSE 512, Spring 2021. HW2, David Read

# %% [markdown]
# For assignment two, I'm working with a subset of a dataset that a group of labmates and I generated recently, profiling single-cell RNA-Seq data from 14 samples of human heart. At a high level, this type of data gives us a readout of the number of unique RNA molecules detected per cell for each of the ~20,000 genes in the human genome. Building off the central dogma of biology, we expect to see the RNA content of cells (referred to as a "transcriptome", as it is RNA transcribed from DNA sequence) reflect the cell's identity and function. For example, if the RNA-Seq data corresponding to a neuron will likely include RNAs corresponding to neurotransmitter receptors. In contrast, RNA-Seq data coming from an immune cell would include RNA for genes involved in pathogen detection and immune signaling.
#
# Previously, I had initially analyzed the dataset to run some initial data cleaning and to annotate the sequences of individual cells with the putative cell type that we think that cell came from. (Initially all "cells" have is count data for the number of RNAs detected in a given cell, but from the genes detected we have to infer what type of cell the sequences correspond to). At a high level I had identified 13,339 cells that appeared to represent endothelium (cells lining vessels inside the body, like arteries/veins/lymphatic capillaries). My work for this assignment picked up where my previous analysis had ended, with the hope of continuing into analysis to explore the endothelial cells in this dataset in greater detail.
#
# My focus was on three questions:
#
# 1) Could I identify and annotate endothelial subtypes within my collection of endothelial cells?
#
# 2) Were there clear differences in endothelial cell proportions by donors?
#
# 3) Were there clear differences in endothelial cell proportions by the anatomical site of the biopsy?

# %%
library(png)
# img <- readPNG(system.file("img", "Rlogo.png", package="png"))
img <- readPNG("Endoth_only__UMAP_partitionLabelcolored.png")
grid::grid.raster(img)
# Out:
# plot without title

# %%
img <- readPNG("Endoth_only__UMAP_Pan-Endothelium.png")
grid::grid.raster(img)
# Out:
# plot without title

# %%
img <- readPNG("Endoth_only_MiaoMarkerssplitBypartitionLabelviolin_expression_no_log.png")
grid::grid.raster(img)
# Out:
# plot without title

# %%
img <- readPNG("Endoth_only__partitionLabelthree_markers_DE.png")
grid::grid.raster(img)
# Out:
# plot without title

# %%
img <- readPNG("Endoth_only_perc_mitochondrial_umis_by_partitionLabel.png")
grid::grid.raster(img)
# Out:
# plot without title

# %%
img <- readPNG("Endoth_only_perc_mitochondrial_umis_by_sample.png")
grid::grid.raster(img)
# Out:
# plot without title

# %%
img <- readPNG("Endoth_only_samplepropsBycluster_cell_typegroupedByDonorcolorByAnatomical_Site.png")
grid::grid.raster(img)
# Out:
# plot without title

# %%
img <- readPNG("Endoth_only_samplepropsBysubtypegroupedByDonorcolorByAnatomical_Site.png")
grid::grid.raster(img)
# Out:
# plot without title

# %%
img <- readPNG("Endoth_only_samplepropsBycluster_cell_typegroupedByAnatomical_SitecolorByDonor.png")
grid::grid.raster(img)
# Out:
# plot without title

# %%
img <- readPNG("Endoth_only_samplepropsBysubtypegroupedByAnatomical_SitecolorByDonor.png")
grid::grid.raster(img)
# Out:
# plot without title
